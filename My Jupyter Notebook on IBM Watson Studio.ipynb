# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Ronie Lamar Patrick Sr. / Retired

# %% [markdown]
# I am interested in data science because, this course will allow me an opportunity to improve my skills in Data Science.

# %%
In cell number 5, I will be adding numbers to determine the result.

# %%
20 + 120
# Out:
# 140

# %%
Run Itemized Deduction

# %%
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='FGnmGGnENSgMEoFIvBAdAaXQBWzybIfZeM0h68nyAmqq',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.us.cloud-object-storage.appdomain.cloud')

bucket = 'testingproject1-donotdelete-pr-0b7nrxm6tzajol'
object_key = 'Itemized Deductions 2019 (Autosaved).xlsx'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']

df_data_0 = pd.read_excel(body.read())
df_data_0.head()
# Out:
#    Donation Receipt ID   Unnamed: 1               Goodwill 2019 Unnamed: 3  \
# 0                  NaN   2080281224            WOMEN'S CLOTHING        NaN
# 1                  NaN  ITEM NUMBER                  ITEM NAME       PRICE
# 2                  NaN            1  Women's All Occasion Dress         18
# 3                  NaN            2       Women's All Sundress          12
# 4                  NaN            3                Jogging Suit         11
#
#   Unnamed: 4   Unnamed: 5
# 0        NaN          NaN
# 1   QUANTITY  TOTAL PRICE
# 2          8          144
# 3          4           48
# 4          4           44
